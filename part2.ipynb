# %%
import pandas as pd

df = pd.read_csv('amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   03/23/14  108-2686189-8480219             Visa - 6357  Amazon.com
# 1   05/14/17  112-5022114-0569828             Visa - 6464  Amazon.com
# 2   05/29/17  112-5728730-9412231             Visa - 6464  Amazon.com
# 3   05/29/17  112-5823981-0236235             Visa - 6293  Amazon.com
# 4   05/29/17  112-9661807-1642650             Visa - 6293  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN   skgreen0608@gmail.com      03/23/14
# 1                    NaN   skgreen0608@gmail.com      05/15/17
# 2                    NaN   skgreen0608@gmail.com      05/29/17
# 3                    NaN   skgreen0608@gmail.com      06/01/17
# 4                    NaN   skgreen0608@gmail.com      05/30/17
#
#   Shipping Address Name Shipping Address Street 1 Shipping Address Street 2  \
# 0   Address unavailable                       NaN                       NaN
# ...

# %%
df.shape
# Out:
# (175, 23)

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   03/23/14  108-2686189-8480219             Visa - 6357  Amazon.com
# 1   05/14/17  112-5022114-0569828             Visa - 6464  Amazon.com
# 2   05/29/17  112-5728730-9412231             Visa - 6464  Amazon.com
# 3   05/29/17  112-5823981-0236235             Visa - 6293  Amazon.com
# 4   05/29/17  112-9661807-1642650             Visa - 6293  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0   skgreen0608@gmail.com      03/23/14
# 1                    0.0   skgreen0608@gmail.com      05/15/17
# 2                    0.0   skgreen0608@gmail.com      05/29/17
# 3                    0.0   skgreen0608@gmail.com      06/01/17
# 4                    0.0   skgreen0608@gmail.com      05/30/17
#
#   Shipping Address Name Shipping Address Street 1 Shipping Address Street 2  \
# 0   Address unavailable                         0                         0
# ...

# %%
#take out $ for total charged column
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# /var/folders/l6/m47rmr4n4l50k957h6nqj9y80000gn/T/ipykernel_77933/2575443921.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   03/23/14  108-2686189-8480219             Visa - 6357  Amazon.com
# 1   05/14/17  112-5022114-0569828             Visa - 6464  Amazon.com
# 2   05/29/17  112-5728730-9412231             Visa - 6464  Amazon.com
# 3   05/29/17  112-5823981-0236235             Visa - 6293  Amazon.com
# 4   05/29/17  112-9661807-1642650             Visa - 6293  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0   skgreen0608@gmail.com      03/23/14
# ...

# %%
#total amount of money spent
df["Total Charged"].sum()
# Out:
# 4871.969999999999

# %%
#average money spent per order
df["Total Charged"].mean()
# Out:
# 27.999827586206884

# %%
#medium money spent
df["Total Charged"].median()
# Out:
# 19.02

# %%
#highest priced order
df["Total Charged"].max()
# Out:
# 203.01

# %%
#lowerst priced order
df["Total Charged"].min()
# Out:
# 0.0

# %%
#take out $ for taxed charged column
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# /var/folders/l6/m47rmr4n4l50k957h6nqj9y80000gn/T/ipykernel_77933/4002746161.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   03/23/14  108-2686189-8480219             Visa - 6357  Amazon.com
# 1   05/14/17  112-5022114-0569828             Visa - 6464  Amazon.com
# 2   05/29/17  112-5728730-9412231             Visa - 6464  Amazon.com
# 3   05/29/17  112-5823981-0236235             Visa - 6293  Amazon.com
# 4   05/29/17  112-9661807-1642650             Visa - 6293  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0   skgreen0608@gmail.com      03/23/14
# 1                    0.0   skgreen0608@gmail.com      05/15/17
# ...

# %%
#total money spent toward taxes
df["Tax Charged"].sum()
# Out:
# 270.97999999999996

# %%
#overall tax rate
df["Tax Charged"].sum() / df["Total Charged"].sum()
# Out:
# 0.05562021112609478

# %%
#convert to datatime data type so the computer can recognize them as dates
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2014-03-23  108-2686189-8480219             Visa - 6357  Amazon.com
# 1 2017-05-14  112-5022114-0569828             Visa - 6464  Amazon.com
# 2 2017-05-29  112-5728730-9412231             Visa - 6464  Amazon.com
# 3 2017-05-29  112-5823981-0236235             Visa - 6293  Amazon.com
# 4 2017-05-29  112-9661807-1642650             Visa - 6293  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0   skgreen0608@gmail.com      03/23/14
# 1                    0.0   skgreen0608@gmail.com      05/15/17
# 2                    0.0   skgreen0608@gmail.com      05/29/17
# 3                    0.0   skgreen0608@gmail.com      06/01/17
# 4                    0.0   skgreen0608@gmail.com      05/30/17
#
#   Shipping Address Name Shipping Address Street 1 Shipping Address Street 2  \
# 0   Address unavailable                         0                         0
# ...

# %%
df.plot.bar(x='Order Date', y='Total Charged', rot=90, figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
#grouping so that each bar represents each day not each order
daily_orders = df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2014-03-23    104.99
# 2017-05-14     25.95
# 2017-05-29    100.36
# 2018-07-23     17.64
# 2018-11-27     51.02
# Name: Total Charged, dtype: float64

# %%
#Total spending bar graph
daily_orders.plot.bar(figsize=(20,10), color='#61D199', xlabel='Order Date', ylabel='Spending', title='Amazon Spending Over Time')
# Out:
# <AxesSubplot:title={'center':'Amazon Spending Over Time'}, xlabel='Order Date', ylabel='Spending'>

# %%
#grouping by year
yearly_spending = df.groupby(pd.Grouper(key='Order Date', freq='1Y')).sum()['Total Charged']
yearly_spending.head()
# Out:
# Order Date
# 2014-12-31    104.99
# 2015-12-31      0.00
# 2016-12-31      0.00
# 2017-12-31    126.31
# 2018-12-31    302.65
# Freq: A-DEC, Name: Total Charged, dtype: float64

# %%
#pie chart spending per year
import matplotlib.pyplot as plt

mylabels= ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

yearly_spending.plot.pie(y='Total Charged', labels = mylabels, title = 'Yearly Spending')
plt.legend(bbox_to_anchor=(1.5, 1.0), loc = 'upper right')

# %%
#bar graph yearly spending
mylabels = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'] 

yearly_spending.plot.bar(figsize=(10,5), color='g', xlabel='Year', ylabel='Total Spending', title='Yearly Amazon Spending')
# Out:
# <AxesSubplot:title={'center':'Yearly Amazon Spending'}, xlabel='Year', ylabel='Total Spending'>

# %%
#multiple lines total charged vs tax charged

import matplotlib.pyplot as plt

plt.plot(df["Order Date"], df["Total Charged"])
plt.plot(df["Order Date"], df["Tax Charged"])

plt.title("Total Charged vs. Tax Charged")
plt.xlabel("Date")
plt.ylabel("Spending")
# Out:
# Text(0, 0.5, 'Spending')
